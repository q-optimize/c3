# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

# %%
base_dir = '/home/usersFWM/froy/Documents/PHD/'
#dir_name_drag = 'hockey_open/2019-10-31_12:35/'
#dir_name_drag = 'hockey_open/2019-10-31_13:30/'
#dir_name_drag = 'hockey_open/2019-11-04_16:23/'
#dir_name_drag = 'hockey_open/2019-11-05_11:15/'
#dir_name_drag = 'hockey_open/2019-11-05_13:41/'
dir_name_drag = 'hockey_open/2019-11-05_15:19/'
savefile_drag = 'drag_N4.pickle'
with open('{}{}{}'.format(base_dir,
                          dir_name_drag, 
                          savefile_drag), 'rb') as file:
    unit_inf_drag = pickle.load(file)
    times_drag = pickle.load(file)
    best_params_drag = pickle.load(file)

# %%
base_dir = '/home/usersFWM/froy/Documents/PHD/'
#dir_name_gauss = 'hockey_open/2019-10-31_12:33/'
#dir_name_gauss = 'hockey_open/2019-10-31_15:22/'
#dir_name_gauss = 'hockey_open/2019-11-04_16:09/'
#dir_name_gauss = 'hockey_open/2019-11-05_11:43/'
#dir_name_gauss = 'hockey_open/2019-11-05_13:45/'
dir_name_gauss = 'hockey_open/2019-11-05_15:20/'
savefile_gauss = 'gauss_N4.pickle'
with open('{}{}{}'.format(base_dir,
                          dir_name_gauss, 
                          savefile_gauss), 'rb') as file:
    unit_inf_gauss = pickle.load(file)
    times_gauss = pickle.load(file)
    best_params_gauss = pickle.load(file)

# %%
plt.plot(times_drag,unit_inf_drag,'r',
         times_gauss,unit_inf_gauss,'b')
plt.ylim([0,0.01])
# Out:
# (0, 0.01)

# %%
plt.plot(times_gauss,unit_inf_gauss,'b')

# %%
plt.plot(times_drag,unit_inf_drag,'r')

# %%
best_params_drag
# Out:
# [array([ 3.29078791e+00, -8.00675235e+04, -1.91233731e-03, -7.00661416e-02]),
#  array([ 2.48900756e+00, -1.19546742e+05,  4.97363024e-04, -4.30940136e-02]),
#  array([ 2.00604032e+00, -2.47579388e+05,  1.71648970e-03, -4.06132280e-02]),
#  array([ 1.67708380e+00, -3.67586542e+05,  1.21671957e-03, -3.67068856e-02]),
#  array([ 1.43154558e+00, -9.90684115e+07,  2.92560751e-01, -2.98289989e-01]),
#  array([ 1.26463060e+00, -6.27595467e+05,  2.51173055e-03, -5.44582086e-02]),
#  array([ 1.12699132e+00, -7.32879093e+05,  3.04783965e-03, -6.91708891e-02]),
#  array([ 1.01449093e+00, -8.25063613e+05,  3.89058024e-03, -8.44036927e-02]),
#  array([ 9.23497754e-01, -9.60862914e+05,  4.53650718e-03, -9.53260768e-02]),
#  array([ 8.46367089e-01, -1.05821224e+06,  5.73292427e-03, -1.07693226e-01]),
#  array([ 7.81779762e-01, -1.23119740e+06,  6.72196880e-03, -1.12043197e-01]),
#  array([ 7.25775408e-01, -1.36842991e+06,  8.41217162e-03, -1.20753957e-01]),
#  array([ 6.77607981e-01, -1.54391695e+06,  9.66048807e-03, -1.22007683e-01]),
#  array([ 6.35207851e-01, -1.67477930e+06,  1.15672990e-02, -1.30475097e-01]),
#  array([ 5.97895701e-01, -1.84843862e+06,  1.30926336e-02, -1.32252959e-01]),
#  array([ 5.64722025e-01, -1.97175924e+06,  1.51492295e-02, -1.42132921e-01]),
#  array([ 5.34950083e-01, -2.12854224e+06,  1.68603880e-02, -1.45136399e-01]),
#  array([ 5.08301781e-01, -2.25609140e+06,  1.91047515e-02, -1.55733303e-01]),
#  array([ 4.83990070e-01, -2.38108971e+06,  2.08731788e-02, -1.59891268e-01]),
#  array([ 4.62124500e-01, -2.48573328e+06,  2.30305809e-02, -1.70465066e-01]),
#  array([ 4.41901168e-01, -2.60532119e+06,  2.50425397e-02, -1.77150136e-01])]

# %%
times_drag
# Out:
# [2.5e-09,
#  3.3333333333333334e-09,
#  4.166666666666667e-09,
#  5e-09,
#  5.8333333333333335e-09,
#  6.666666666666667e-09,
#  7.500000000000001e-09,
#  8.333333333333334e-09,
#  9.166666666666666e-09,
#  1e-08,
#  1.0833333333333334e-08,
#  1.1666666666666667e-08,
#  1.25e-08,
#  1.3333333333333334e-08,
#  1.4166666666666668e-08,
#  1.5000000000000002e-08,
#  1.5833333333333333e-08,
#  1.6666666666666667e-08,
#  1.75e-08,
#  1.8333333333333332e-08,
#  1.9166666666666666e-08]

# %%
unit_inf_drag
# Out:
# [0.009342954157459449,
#  0.00774070804402871,
#  0.0053637642875753455,
#  0.0037290707372285015,
#  0.0023687058747372536,
#  0.0015341892089481002,
#  0.0008259462680201279,
#  0.0004254166275419191,
#  0.00018217509962437095,
#  6.546494265091685e-05,
#  2.1704232045727245e-05,
#  6.166602243173891e-06,
#  2.39789773992527e-06,
#  1.1408146937119668e-06,
#  2.068110935837808e-07,
#  1.0559511208763084e-06,
#  2.1486757377786603e-06,
#  5.566381865329539e-06,
#  5.923936805207752e-06,
#  5.9854190310737465e-06,
#  4.58277856529854e-06]

# %%
best_params_gauss
# Out:
# [array([ 3.29492373e+00,  9.99088882e+07, -1.27116729e-01]),
#  array([ 2.49060884e+00,  4.90650948e+07, -8.14689255e-02]),
#  array([ 2.00679035e+00,  2.99082364e+07, -6.11071451e-02]),
#  array([ 1.67741027e+00,  1.86516509e+07, -4.63425770e-02]),
#  array([ 1.44397916e+00,  1.68124620e+07, -4.84468687e-02]),
#  array([ 1.26495286e+00,  1.53719322e+07, -5.08253641e-02]),
#  array([ 1.12738725e+00,  1.53767905e+07, -5.73668307e-02]),
#  array([ 1.01492671e+00,  1.51845831e+07, -6.28196007e-02]),
#  array([ 9.23920168e-01,  1.40448034e+07, -6.42382565e-02]),
#  array([ 8.46813288e-01,  1.32188280e+07, -6.56520276e-02]),
#  array([ 7.82147274e-01,  1.14701599e+07, -6.20790526e-02]),
#  array([ 7.26111976e-01,  1.04612267e+07, -6.05956417e-02]),
#  array([ 6.77885718e-01,  8.86825565e+06, -5.54147719e-02]),
#  array([ 6.35470130e-01,  8.11304270e+06, -5.36857671e-02]),
#  array([ 5.98120283e-01,  6.93903132e+06, -4.91523655e-02]),
#  array([ 5.64939292e-01,  6.44652513e+06, -4.79916300e-02]),
#  array([ 5.35143237e-01,  5.58980015e+06, -4.42425557e-02]),
#  array([ 5.08492745e-01,  5.21977072e+06, -4.31944616e-02]),
#  array([ 4.84165151e-01,  4.58170018e+06, -4.00522379e-02]),
#  array([ 4.62296252e-01,  4.27706226e+06, -3.89626986e-02]),
#  array([ 4.42063477e-01,  3.82687678e+06, -3.66003957e-02])]

# %%
times_gauss
# Out:
# [2.5e-09,
#  3.3333333333333334e-09,
#  4.166666666666667e-09,
#  5e-09,
#  5.8333333333333335e-09,
#  6.666666666666667e-09,
#  7.500000000000001e-09,
#  8.333333333333334e-09,
#  9.166666666666666e-09,
#  1e-08,
#  1.0833333333333334e-08,
#  1.1666666666666667e-08,
#  1.25e-08,
#  1.3333333333333334e-08,
#  1.4166666666666668e-08,
#  1.5000000000000002e-08,
#  1.5833333333333333e-08,
#  1.6666666666666667e-08,
#  1.75e-08,
#  1.8333333333333332e-08,
#  1.9166666666666666e-08]

# %%
unit_inf_gauss
# Out:
# [0.00942180311575136,
#  0.007747928531655401,
#  0.005366728181847913,
#  0.0037305310711607254,
#  0.0024275133282360972,
#  0.0015356481377329922,
#  0.0008274277050777101,
#  0.0004266387197118249,
#  0.00018297560837232663,
#  6.589301755421939e-05,
#  2.1871457114963633e-05,
#  6.189536228440318e-06,
#  2.3935280698550443e-06,
#  1.1276629746648226e-06,
#  2.0212746187908692e-07,
#  1.0498958626925514e-06,
#  2.139813332191487e-06,
#  5.546518396792877e-06,
#  5.90538071998381e-06,
#  5.967686404151351e-06,
#  4.571100469807909e-06]
