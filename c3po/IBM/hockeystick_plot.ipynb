# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

# %%
base_dir = '/home/usersFWM/froy/Documents/PHD/'
#dir_name_drag = 'hockey_open/2019-10-31_12:35/'
dir_name_drag = 'hockey_open/2019-10-31_13:30/'
savefile_drag = 'drag_N4.pickle'
with open('{}{}{}'.format(base_dir,
                          dir_name_drag, 
                          savefile_drag), 'rb') as file:
    overlap_inf_drag = pickle.load(file)
    times_drag = pickle.load(file)
    best_params_drag = pickle.load(file)

# %%
base_dir = '/home/usersFWM/froy/Documents/PHD/'
#dir_name_gauss = 'hockey_open/2019-10-31_12:33/'
dir_name_gauss = 'hockey_open/2019-10-31_15:22/'
savefile_gauss = 'gauss_N4.pickle'
with open('{}{}{}'.format(base_dir,
                          dir_name_gauss, 
                          savefile_gauss), 'rb') as file:
    overlap_inf_gauss = pickle.load(file)
    times_gauss = pickle.load(file)
    best_params_gauss = pickle.load(file)

# %%
plt.plot(times_drag,overlap_inf_drag,
         times_gauss,overlap_inf_gauss)
# Out:
# [<matplotlib.lines.Line2D at 0x7fb6853d0f90>,
#  <matplotlib.lines.Line2D at 0x7fb6b59063d0>]

# %%
plt.plot(times_drag,overlap_inf_drag)

# %%
best_params_drag[3]
# Out:
# array([ 1.70349896e+00,  3.08792384e+07, -2.53171726e-01])

# %%
times_drag[3]
# Out:
# 5e-09

# %%
overlap_inf_drag[3]
# Out:
# 3.638832196461994e-05

# %%
best_params_gauss[3]
# Out:
# array([ 1.68732807e+00, -3.85382920e+06])

# %%
times_gauss[3]
# Out:
# 5e-09

# %%
overlap_inf_gauss[3]
# Out:
# 2.2461239081672524e-05
